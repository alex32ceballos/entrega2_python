# %% [markdown]
# Sirve para buscar los modulos en esa ubicacion

# %%
import sys
sys.path.append("../src")

# %% [markdown]
# Ejercicio 1 - Estadisticas de un texto

# %%
import estadisticas_texto
estadisticas_texto.estadisticasTexto(estadisticas_texto.text)
# Out:
# Total de lineas:  19
# Total de palabras:  137
# Promedio de palabras por línea:  7.21
# Líneas por encima del promedio (7.21 palabras)
# - "Special cases aren't special enough to break the rules." (9 palabras)
# - "In the face of ambiguity, refuse the temptation to guess." (10 palabras)
# - "There should be one-- and preferably only one --obvious way
# to do it." (13 palabras)
# - "Although that way may not be obvious at first unless you're
# Dutch." (12 palabras)
# - "Although never is often better than *right* now." (8 palabras)
# - "If the implementation is hard to explain, it's a bad idea." (11 palabras)
# - "If the implementation is easy to explain, it may be a good
# idea." (13 palabras)
# - "Namespaces are one honking great idea -- let's do more of
# those!." (12 palabras)

# %% [markdown]
# Ejercicio 2 - duracion de playlist

# %%
import duracion_playlist
duracion_playlist.duracionesPlaylist()
# Out:
# Duracion total: 46m 53s
# Cancion mas larga: 'Stairway to Heaven' (8:02)
# Cancion mas corta: 'Imagine' (3:07)
# Duracion total: 46m 53s
# Cancion mas larga: 'Stairway to Heaven' (8:02)
# Cancion mas corta: 'Imagine' (3:07)

# %% [markdown]
# Ejercicio 3 - filtro de spoilers

# %%
import filtro_spoilers
filtro_spoilers.filtroSpoilers(filtro_spoilers.review)
# Out:
# Ingrese las palabras spoiler (separadas por coma):  MarTE
# La película sigue a un grupo de astronautas que viajan a *****
# en una misión de rescate. El capitán Torres lidera al equipo a
# través de tormentas solares y fallos en el sistema de
# navegación. Al llegar a ***** descubren que la base está
# abandonada y los suministros destruidos. Torres decide
# sacrificar la nave nodriza para salvar al equipo y logran
# volver a la Tierra en una cápsula de emergencia. El final
# revela que Torres sobrevivió gracias a un pasaje secreto.

# %% [markdown]
# Ejercicio 4 - validacion de email

# %%
import validacion_email 
validacion_email.validacionEmail()
# Out:
# Ingrese un email:  no
# El email no es válido

# %% [markdown]
# Ejercicio 5 - calculadora de costo de envio

# %%
import calculadora_costo_envio as cce
cce.calcular(cce.zonasValidas, cce.hastaUnKG, cce.entreUnoYcincoKG, cce.masCincoKG)
# Out:
# Ingrese peso del paquete:  32
# Ingrese la zona de destino (local/regional/nacional):  locAL
# Costo de envio:  2000

# %% [markdown]
# Ejercicio 6 - analisis de hashtags

# %%
import analisis_hashtags
analisis_hashtags.analisisHashtags(analisis_hashtags.posts)
# Out:
# Hashtags trending (más de una aparición):
# #Python: 3
# #Programación: 3
# #InteligenciaArtificial: 3
# #Motivación: 2
# #SerieAdicta: 2
# #Tecnología: 2
# Total de hashtags únicos:  13

# %% [markdown]
# Ejercicio 7 - sorteo de amigo invisible

# %%
import sorteo_amigo_invisible
sorteo_amigo_invisible.sorteoAmigoInvisible()
# Out:
# ingrese los participantes (Separados por coma):  no
# hay menos de 3 nombres, el sorteo no puede llevarse a cabo

# %% [markdown]
# Ejercicio 8 - cifrado césar

# %%
import cifrado_cesar
cifrado_cesar.cifradoCesar()
# Out:
# Ingrese un mensaje:  asd
# Ingrese el desplazamiento:  9999999
# Mensaje cifrado:  jbm
# Mensaje descifrado:  asd

# %%
ejercicio 9 - normalizacion de registros de alumnos

# %%
import normalizacion_registros_alumnos as nra
nra.normalizarRegistrosAlumnos(nra.students)
# Out:
# Registros limpios de alumnos:
# -----------------------------------------------------
# Nombre                   Nota               Estado
#
# Ana García                9.0               Aprobado
# Carlos Ruiz               6.0               Aprobado
# Gabriela Ríos             5.0               Aprobado
# Laura Méndez              8.0               Aprobado
# María Fernández           10.0              Aprobado
# Pedro López               4.0               Desaprobado
# Sofía Torres              9.0               Aprobado
# Total de alumnos válidos: 7

# %%
Ejercicio 10 - simulacion de competencia de cocina

# %%
import competencia_cocina_ranking as ccr
ccr.competenciaCocinaRanking(ccr.rounds)
# Out:
# Ronda 1 - Entrada
# Ganador: Camila (26)
# Cocinero      puntaje     rondas ganadas     mejor ronda      promedio
# Camila           26             1                 26               26
# Valentina        24             0                 24               24
# Lucía            24             0                 24               24
# Mateo            22             0                 22               22
# Santiago         19             0                 19               19
#
# Ronda 2 - Plato principal
# Ganador: Valentina (26)
# Cocinero      puntaje     rondas ganadas     mejor ronda      promedio
# Valentina        50             1                 26             25.0
# Mateo            46             0                 24             23.0
# Camila           46             1                 26             23.0
# Lucía            46             0                 24             23.0
# Santiago         44             0                 25             22.0
#
# Ronda 3 - Postre
# ...
